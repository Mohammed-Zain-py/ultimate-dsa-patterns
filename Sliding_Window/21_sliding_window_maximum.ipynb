# %% [markdown]
# # Sliding Window Problem 21 — Sliding Window Maximum
#
# ## Problem Statement
#
# Given an array `nums` and an integer `k`,
# return the maximum value in every sliding window of size `k`.
#
# Example:
#
# nums = [1,3,-1,-3,5,3,6,7]
# k = 3
#
# Output:
# [3,3,5,5,6,7]

# %% [markdown]
# # Brute Force Approach
#
# For every window of size `k`,
# scan all elements and find the maximum.

# %%
def sliding_max_bruteforce(nums, k):
    result = []

    for i in range(len(nums) - k + 1):
        result.append(max(nums[i:i + k]))

    return result


print(sliding_max_bruteforce([1,3,-1,-3,5,3,6,7], 3))
# Out:
# [3, 3, 5, 5, 6, 7]

# %% [markdown]
# # Complexity of Brute Force
#
# Time Complexity: O(n * k)
#
# Too slow for large inputs.

# %% [markdown]
# # Optimal Idea — Sliding Window + Deque
#
# Use a deque to store indices.
#
# Maintain it in decreasing order of values.
#
# The front always stores the maximum.

# %% [markdown]
# # Key Observation
#
# Before inserting a new element:
#
# remove all smaller elements from the back.
#
# Because they can never become the maximum.

# %% [markdown]
# # Window Dry Run
#
# nums = [1,3,-1,-3,5,3,6,7]
# k = 3
#
# | window | max |
# |--------|-----|
# | [1,3,-1] | 3 |
# | [3,-1,-3] | 3 |
# | [-1,-3,5] | 5 |
# | [-3,5,3] | 5 |
# | [5,3,6] | 6 |
# | [3,6,7] | 7 |

# %%
from collections import deque

class Solution:
    def maxSlidingWindow(self, nums, k):
        dq = deque()
        result = []

        for i in range(len(nums)):
            while dq and dq[0] <= i - k:
                dq.popleft()

            while dq and nums[dq[-1]] < nums[i]:
                dq.pop()

            dq.append(i)

            if i >= k - 1:
                result.append(nums[dq[0]])

        return result

# %% [markdown]
# # Complexity Comparison
#
# Brute Force:
# - Time → O(n * k)
#
# Optimal:
# - Time → O(n)
# - Space → O(k)

# %% [markdown]
# # Pattern Takeaway
#
# This is one of the most important **medium-hard deque sliding window problems**.
#
# Very frequently asked.
