# %% [markdown]
# # Insertion Sort on Linked List

# %% [markdown]
# ## Problem Statement
#
# Sort a Linked List using Insertion Sort.
#
#
# Input
#
# ```text
# 4 → 2 → 1 → 3
# ```
#
#
# Output
#
# ```text
# 1 → 2 → 3 → 4
# ```
#
#
# Explanation
#
# ```text
# Take one node
# at a time.
#
# Insert it into
# its correct position
# in the sorted part.
# ```

# %% [markdown]
# ## Problem Explanation
#
#
# Original
#
# ```text
# 4 → 2 → 1 → 3
# ```
#
#
# Initially
#
# ```text
# Sorted
#
# 4
# ```
#
#
# Insert
#
# ```text
# 2
#
# ↓
#
# 2 → 4
# ```
#
#
# Insert
#
# ```text
# 1
#
# ↓
#
# 1 → 2 → 4
# ```
#
#
# Insert
#
# ```text
# 3
#
# ↓
#
# 1 → 2 → 3 → 4
# ```
#
#
# Observation
#
#
# Unlike Merge Sort,
#
# the sorted portion
#
# grows one node
#
# at a time.

# %% [markdown]
# ## Brute Force
#
#
# Store values.
#
#
# Sort.
#
#
# Rebuild list.
#
#
# Simple.
#
# Does not use
# Insertion Sort.

# %%
values = [4, 2, 1, 3]

values.sort()

print(values)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Complexity
#
# ```text
# Time  → O(N log N)
#
# Space → O(N)
# ```

# %% [markdown]
# ## Optimal Approach
#
#
# Maintain
#
#
# ```text
# Sorted List
# ```
#
#
# For every node
#
#
# ```text
# Find Position
#
# ↓
#
# Insert
# ```
#
#
# Repeat until
#
# all nodes
#
# are processed.

# %% [markdown]
# ## Dry Run
#
#
# Initial
#
# ```text
# 4
# ```
#
#
# Insert
#
# ```text
# 2
#
# ↓
#
# 2 → 4
# ```
#
#
# Insert
#
# ```text
# 1
#
# ↓
#
# 1 → 2 → 4
# ```
#
#
# Insert
#
# ```text
# 3
#
# ↓
#
# 1 → 2 → 3 → 4
# ```

# %%
class Solution:

    def insertionSortList(self, head):

        dummy = ListNode(0)

        current = head

        while current:

            prev = dummy

            while prev.next and prev.next.val < current.val:

                prev = prev.next

            nxt = current.next

            current.next = prev.next

            prev.next = current

            current = nxt

        return dummy.next

# %% [markdown]
# ## Complexity
#
# ```text
# Time  → O(N²)
#
# Space → O(1)
# ```

# %% [markdown]
# ## Comparison
#
#
# | Algorithm | Time | Space |
# |---|---:|---:|
# | Merge Sort | O(N log N) | O(log N) |
# | Insertion Sort | O(N²) | O(1) |

# %% [markdown]
# ## Takeaway
#
# ```text
# Grow
#
# ↓
#
# Find Position
#
# ↓
#
# Insert
#
# ↓
#
# Repeat
# ```
#
#
# Insertion Sort demonstrates incremental sorting through pointer insertion, while Merge Sort remains the preferred choice for efficiently sorting large linked lists.
