# %% [markdown]
# # Linked List Interview Cheatsheet

# %% [markdown]
# # Interview Flow
#
# Question
#
# ↓
#
# Identify Pattern
#
# ↓
#
# Choose Pointer Strategy
#
# ↓
#
# Draw Diagram
#
# ↓
#
# Write Code
#
# ↓
#
# Dry Run
#
# ↓
#
# Edge Cases

# %% [markdown]
# # Which Pattern Should I Use?
#
# | If Question Says | Think |
# |------------------|-------|
# | Middle | Fast Slow |
# | Cycle | Floyd |
# | Reverse | 3 Pointer |
# | Merge | Dummy |
# | K Nodes | Block Reverse |
# | Sorted | Merge |
# | Delete | Dummy |
# | Position | Traversal |

# %% [markdown]
# # Pointer Templates
#
# Traversal
#
# Fast Slow
#
# Reverse
#
# Dummy
#
# Merge
#
# Block Reverse

# %% [markdown]
# # Time Complexities
#
# Traversal
#
# Search
#
# Insert
#
# Delete
#
# Reverse
#
# Merge
#
# Sort
#
# Cycle

# %% [markdown]
# # Common Mistakes
#
# Lose next pointer
#
# Forget dummy
#
# Wrong reconnect order
#
# Infinite loop
#
# NULL check
#
# Wrong head return

# %% [markdown]
# # Edge Cases
#
# Empty List
#
# One Node
#
# Two Nodes
#
# Even Length
#
# Odd Length
#
# Delete Head
#
# Delete Tail
#
# Entire List

# %% [markdown]
# # Dummy Node Checklist
#
# When should I use it?
#
# When should I avoid it?

# %% [markdown]
# # Fast Slow Checklist
#
# Middle
#
# Cycle
#
# Cycle Start
#
# Palindrome

# %% [markdown]
# # Reverse Checklist
#
# Whole
#
# Partial
#
# K Group
#
# Reorder

# %% [markdown]
# # Top Interview Questions
#
# Reverse List
#
# Merge Two Lists
#
# Merge K Lists
#
# Remove Nth From End
#
# Copy Random Pointer
#
# Reorder List
#
# Detect Cycle
#
# Reverse Between
#
# ...

# %% [markdown]
# # Final Advice
#
# Draw first.
#
# Think in pointers.
#
# Reconnect carefully.
#
# Never memorize.
#
# Recognize patterns.
