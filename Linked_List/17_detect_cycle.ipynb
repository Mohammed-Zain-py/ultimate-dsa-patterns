# %% [markdown]
# # Detect Cycle in Linked List

# %% [markdown]
# ## Problem Statement
#
#
# Determine whether a cycle exists.
#
#
# Input
#
#
# ```text
# 1 → 2 → 3 → 4
#      ↑     ↓
#      └─────┘
# ```
#
#
# Output
#
#
# ```text
# True
# ```
#
#
# Explanation
#
#
# ```text
# Detect whether traversal
# can run forever.
# ```

# %% [markdown]
# ## Problem Explanation
#
#
# Normal List
#
#
# ```text
# 1 → 2 → 3 → NULL
# ```
#
#
# Cycle
#
#
# ```text
# 1 → 2 → 3 → 4
#     ↑       ↓
#     └───────┘
# ```
#
#
# Observation
#
#
# Traversal never reaches:
#
#
# ```text
# NULL
# ```
#
#
# Idea
#
#
# ```text
# Slow → 1
#
# Fast → 2
# ```
#
#
# If they meet:
#
#
# ```text
# Cycle Exists
# ```

# %% [markdown]
# ## Brute Force
#
#
# Store visited nodes.
#
#
# If repeated:
#
#
# ```text
# Cycle
# ```
#
#
# Extra memory.

# %%
visited = set()

print("Store references")
# Out:
# Store references

# %% [markdown]
# ## Complexity
#
#
# ```text
# Time  → O(N)
#
# Space → O(N)
# ```

# %% [markdown]
# ## Optimal Approach
#
#
# Use:
#
#
# ```text
# slow
#
# fast
# ```
#
#
# Movement
#
#
# ```text
# slow += 1
#
# fast += 2
# ```
#
#
# Rule
#
#
# ```text
# Meet
#
# ↓
#
# Cycle
# ```
#
#
# Reach NULL
#
#
# ```text
# No Cycle
# ```

# %% [markdown]
# ## Dry Run
#
#
# Start
#
#
# ```text
# 1 → 2 → 3 → 4
# S
# F
# ```
#
#
# Move
#
#
# ```text
# 1 → 2 → 3 → 4
#     S
#         F
# ```
#
#
# Move
#
#
# ```text
# 1 → 2 → 3 → 4
#         S
#         F
# ```
#
#
# Meet
#
#
# ```text
# True
# ```

# %%
class Solution:

    def hasCycle(self, head):

        slow = head

        fast = head

        while fast and fast.next:

            slow = slow.next

            fast = fast.next.next

            if slow == fast:

                return True

        return False

# %% [markdown]
# ## Complexity
#
#
# ```text
# Time  → O(N)
#
# Space → O(1)
# ```

# %% [markdown]
# ## Pattern Recognition
#
#
# ```text
# Different Speeds
#
# ↓
#
# Meeting Point
#
# ↓
#
# Cycle
# ```

# %% [markdown]
# ## Takeaway
#
#
# ```text
# Slow
#
# +
#
# Fast
#
# ↓
#
# Meet
#
# ↓
#
# Cycle
# ```
#
#
# Floyd's algorithm is one of the most reusable pointer techniques.
