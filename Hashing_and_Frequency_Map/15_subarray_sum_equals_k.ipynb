# %% [markdown]
# # Hashing Problem 15 — Subarray Sum Equals K
#
# ## Problem Statement
#
# Given an array `nums`
# and an integer `k`,
#
# return the total number of subarrays
# whose sum equals `k`.
#
# Example:
#
# nums = [1,1,1]
# k = 2
#
# Output:
# 2

# %% [markdown]
# # Brute Force Approach
#
# Generate every possible subarray.
#
# Calculate its sum.
#
# If sum equals `k`,
# increase count.

# %%
def subarray_sum_bruteforce(nums, k):
    count = 0

    for i in range(len(nums)):
        current_sum = 0

        for j in range(i, len(nums)):
            current_sum += nums[j]

            if current_sum == k:
                count += 1

    return count


print(subarray_sum_bruteforce([1,1,1], 2))
# Out:
# 2

# %% [markdown]
# # Complexity of Brute Force
#
# Time Complexity: O(n²)
#
# Too slow for large arrays.

# %% [markdown]
# # Optimal Idea — Prefix Sum + Hashmap
#
# Store prefix sums in a hashmap.
#
# For every current prefix sum:
#
# required = current_sum - k
#
# If required already exists,
# a valid subarray is found.

# %% [markdown]
# # Why This Works
#
# Suppose:
#
# current_sum = 10
# k = 4
#
# If a previous prefix sum = 6 existed,
#
# then:
#
# 10 - 6 = 4
#
# So the subarray between them sums to k.

# %% [markdown]
# # Dry Run
#
# nums = [1,1,1]
# k = 2
#
# Prefix sums:
#
# 1
# 2
# 3
#
# At current_sum = 3:
#
# required = 1
#
# 1 already exists.
#
# So one valid subarray found.

# %%
class Solution:
    def subarraySum(self, nums, k):
        prefix_count = {0: 1}

        current_sum = 0
        count = 0

        for num in nums:
            current_sum += num

            required = current_sum - k

            if required in prefix_count:
                count += prefix_count[required]

            prefix_count[current_sum] = (
                prefix_count.get(current_sum, 0) + 1
            )

        return count

# %% [markdown]
# # Complexity Comparison
#
# Brute Force:
# - Time → O(n²)
#
# Optimal:
# - Time → O(n)
# - Space → O(n)

# %% [markdown]
# # Pattern Takeaway
#
# This is one of the most important
# prefix sum + hashmap interview problems.
#
# A must-master question.
