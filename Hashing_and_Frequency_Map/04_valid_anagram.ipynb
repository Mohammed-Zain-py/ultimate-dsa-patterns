# %% [markdown]
# # Hashing Problem 4 — Valid Anagram
#
# ## Problem Statement
#
# Given two strings `s` and `t`,
# return `True` if `t` is an anagram of `s`.
#
# An anagram contains the same characters
# with the same frequencies.
#
# Example:
#
# s = "anagram"
# t = "nagaram"
#
# Output:
# True

# %% [markdown]
# # Brute Force Approach
#
# Sort both strings.
#
# If sorted versions are equal,
# they are anagrams.

# %%
def valid_anagram_bruteforce(s, t):
    return sorted(s) == sorted(t)


print(valid_anagram_bruteforce("anagram", "nagaram"))
# Out:
# True

# %% [markdown]
# # Complexity of Brute Force
#
# Time Complexity: O(n log n)
#
# Because sorting is required.

# %% [markdown]
# # Optimal Idea — Frequency Map
#
# Count character frequencies for both strings.
#
# If frequency maps are equal,
# strings are anagrams.

# %% [markdown]
# # Why This Works
#
# Anagrams must contain:
#
# - same characters
# - same frequency counts

# %% [markdown]
# # Dry Run
#
# s = "anagram"
# t = "nagaram"
#
# Frequency maps:
#
# a → 3
# n → 1
# g → 1
# r → 1
# m → 1
#
# Both strings produce identical counts.

# %%
from collections import Counter

class Solution:
    def isAnagram(self, s, t):
        return Counter(s) == Counter(t)

# %% [markdown]
# # Complexity Comparison
#
# Brute Force:
# - Time → O(n log n)
#
# Optimal:
# - Time → O(n)
# - Space → O(n)

# %% [markdown]
# # Pattern Takeaway
#
# Classic frequency-map interview problem.
#
# Very frequently asked.
