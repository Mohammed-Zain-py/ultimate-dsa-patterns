# %% [markdown]
# # Hashing Problem 26 — Hard Hashing Revision Problems
#
# This notebook revises the most important
# advanced hashing interview problems.
#
# Goal:
#
# - strengthen pattern recognition
# - improve recall speed
# - revise transformations

# %% [markdown]
# # Problem 1 — Subarray Sum Equals K
#
# Pattern:
# prefix sum + hashmap
#
# Core idea:
#
# required = current_sum - k

# %% [markdown]
# # Problem 2 — Subarray Sum Divisible By K
#
# Pattern:
# prefix remainder hashmap
#
# Core idea:
#
# same remainder repeats

# %% [markdown]
# # Problem 3 — Count Subarrays With XOR K
#
# Pattern:
# prefix xor hashmap
#
# Core idea:
#
# required = current_xor ^ k

# %% [markdown]
# # Problem 4 — Longest Zero Sum Subarray
#
# Pattern:
# repeated prefix sum
#
# Core idea:
#
# same prefix appears again

# %% [markdown]
# # Problem 5 — Equal 0's and 1's
#
# Transformation:
#
# 0 → -1
#
# Then solve:
# subarray sum = 0

# %% [markdown]
# # Most Important Learning
#
# Different questions often use:
#
# the SAME hidden pattern.

# %% [markdown]
# # Interview Mindset
#
# Always ask:
#
# 1. can prefix help?
# 2. can hashmap store history?
# 3. am I looking for repeated states?
# 4. can transformation simplify problem?

# %% [markdown]
# # Final Takeaway
#
# Advanced hashing problems become easier
# once pattern recognition improves.
