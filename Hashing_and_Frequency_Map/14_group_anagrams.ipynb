# %% [markdown]
# # Hashing Problem 14 — Group Anagrams
#
# ## Problem Statement
#
# Given an array of strings `strs`,
# group the anagrams together.
#
# Example:
#
# strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output:
# [["eat","tea","ate"],["tan","nat"],["bat"]]

# %% [markdown]
# # Brute Force Approach
#
# Compare every string
# with every other string.
#
# If sorted versions match,
# they belong to the same group.

# %%
def group_anagrams_bruteforce(strs):
    groups = []
    used = [False] * len(strs)

    for i in range(len(strs)):
        if used[i]:
            continue

        current_group = [strs[i]]
        used[i] = True

        for j in range(i + 1, len(strs)):
            if sorted(strs[i]) == sorted(strs[j]):
                current_group.append(strs[j])
                used[j] = True

        groups.append(current_group)

    return groups


print(group_anagrams_bruteforce(
    ["eat","tea","tan","ate","nat","bat"]
))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# # Complexity of Brute Force
#
# Time Complexity: O(n² * k log k)
#
# Where:
# - n = number of strings
# - k = average string length

# %% [markdown]
# # Optimal Idea — Hashmap Grouping
#
# Anagrams produce the same sorted string.
#
# Use the sorted string as hashmap key.

# %% [markdown]
# # Key Observation
#
# All anagrams share:
#
# same characters
# same frequencies
#
# So their sorted forms become identical.

# %% [markdown]
# # Dry Run
#
# "eat" → "aet"
# "tea" → "aet"
# "ate" → "aet"
#
# Group under:
#
# "aet"

# %%
class Solution:
    def groupAnagrams(self, strs):
        groups = {}

        for word in strs:
            key = "".join(sorted(word))

            if key not in groups:
                groups[key] = []

            groups[key].append(word)

        return list(groups.values())

# %% [markdown]
# # Complexity Comparison
#
# Brute Force:
# - Time → O(n² * k log k)
#
# Optimal:
# - Time → O(n * k log k)
# - Space → O(n)

# %% [markdown]
# # Important Note
#
# Later we will learn an even better approach:
#
# frequency-count tuple key
#
# which avoids sorting.

# %% [markdown]
# # Pattern Takeaway
#
# This is one of the most important hashmap grouping interview problems.
#
# A must-master question.
