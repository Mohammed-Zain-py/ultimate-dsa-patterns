# %% [markdown]
# # Hashing Problem 8 — Top K Frequent Elements
#
# ## Problem Statement
#
# Given an integer array `nums`
# and an integer `k`,
# return the `k` most frequent elements.
#
# Example:
#
# nums = [1,1,1,2,2,3]
# k = 2
#
# Output:
# [1,2]

# %% [markdown]
# # Brute Force Approach
#
# Count frequencies manually.
#
# Sort elements based on frequency.
#
# Return the top k elements.

# %%
def top_k_frequent_bruteforce(nums, k):
    freq = {}

    for num in nums:
        freq[num] = freq.get(num, 0) + 1

    items = list(freq.items())

    items.sort(key=lambda x: x[1], reverse=True)

    result = []

    for i in range(k):
        result.append(items[i][0])

    return result


print(top_k_frequent_bruteforce([1,1,1,2,2,3], 2))
# Out:
# [1, 2]

# %% [markdown]
# # Complexity of Brute Force
#
# Time Complexity: O(n log n)
#
# Because sorting is required.

# %% [markdown]
# # Better Idea — Bucket Frequency Thinking
#
# Instead of sorting everything,
#
# group elements based on frequency.

# %% [markdown]
# # Key Observation
#
# Maximum possible frequency = n
#
# So we can create buckets:
#
# index = frequency
# value = elements with that frequency

# %% [markdown]
# # Dry Run
#
# nums = [1,1,1,2,2,3]
#
# Frequency map:
#
# 1 → 3
# 2 → 2
# 3 → 1
#
# Buckets:
#
# 1 → [3]
# 2 → [2]
# 3 → [1]

# %%
class Solution:
    def topKFrequent(self, nums, k):
        freq = {}

        for num in nums:
            freq[num] = freq.get(num, 0) + 1

        buckets = [[] for _ in range(len(nums) + 1)]

        for num, count in freq.items():
            buckets[count].append(num)

        result = []

        for i in range(len(buckets) - 1, -1, -1):
            for num in buckets[i]:
                result.append(num)

                if len(result) == k:
                    return result

# %% [markdown]
# # Complexity Comparison
#
# Brute Force:
# - Time → O(n log n)
#
# Optimal:
# - Time → O(n)
# - Space → O(n)

# %% [markdown]
# # Pattern Takeaway
#
# This is an important hashmap + bucket frequency problem.
#
# Very commonly asked in interviews.
