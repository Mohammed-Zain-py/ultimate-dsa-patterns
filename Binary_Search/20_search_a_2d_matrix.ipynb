# %% [markdown]
# # Binary Search Problem 20 — Search a 2D Matrix
#
# ## Problem Statement
#
# You are given an `m × n` matrix.
#
# Properties:
#
# - Each row is sorted.
#
# - First element of a row
# is greater than
# last element
# of previous row.
#
# Return:
#
# True
#
# if target exists,
#
# otherwise:
#
# False

# %% [markdown]
# # Problem Explanation
#
# Example 1:
#
# Input:
#
# matrix = [
# [1,3,5,7],
# [10,11,16,20],
# [23,30,34,60]
# ]
#
# target = 3
#
#
# Output:
#
# True
#
#
# Explanation:
#
# 3 exists
# inside matrix.
#
#
#
# Example 2:
#
# Input:
#
# matrix = [
# [1,3,5],
# [7,9,11]
# ]
#
# target = 8
#
#
# Output:
#
# False
#
#
# Explanation:
#
# 8 does not exist.

# %% [markdown]
# # Brute Force Approach
#
# Traverse:
#
# every row
#
# every column
#
# until target is found.

# %%
def search_matrix_bruteforce(matrix, target):
    for row in matrix:
        for value in row:
            if value == target:
                return True

    return False


print(search_matrix_bruteforce(
    [
        [1, 3, 5, 7],
        [10, 11, 16, 20],
        [23, 30, 34, 60]
    ],
    3
))
# Out:
# True

# %% [markdown]
# # Complexity of Brute Force
#
# Time Complexity:
#
# O(m × n)

# %% [markdown]
# # Optimal Idea
#
# Treat matrix
#
# as one sorted array.
#
# Convert:
#
# index
#
# into
#
# row and column.

# %% [markdown]
# # Dry Run
#
# rows = 3
#
# cols = 4
#
#
# mid = 5
#
#
# row = 1
#
# col = 1
#
#
# matrix[1][1]
#
# = 11

# %%
class Solution:
    def searchMatrix(self, matrix, target):
        rows = len(matrix)
        cols = len(matrix[0])

        left = 0
        right = rows * cols - 1

        while left <= right:
            mid = left + (right - left) // 2

            row = mid // cols
            col = mid % cols

            value = matrix[row][col]

            if value == target:
                return True

            elif value < target:
                left = mid + 1

            else:
                right = mid - 1

        return False

# %% [markdown]
# # Complexity Comparison
#
# Brute Force:
#
# Time → O(m × n)
#
# Space → O(1)
#
#
# Optimal:
#
# Time → O(log(m × n))
#
# Space → O(1)

# %% [markdown]
# # Important Observation
#
# 2D matrix
#
# became
#
# 1D Binary Search.

# %% [markdown]
# # Pattern Takeaway
#
# Sometimes
#
# changing representation
#
# creates Binary Search.
