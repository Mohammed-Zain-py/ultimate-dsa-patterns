# %% [markdown]
# # Binary Search — Complete Revision
#
# This notebook revises
# the complete Binary Search module.
#
# Goal:
#
# - recall patterns
#
# - identify signals
#
# - connect problems

# %% [markdown]
# # Core Binary Search Idea
#
# Search Space
#
# ↓
#
# Check Mid
#
# ↓
#
# Discard Half
#
# ↓
#
# Repeat

# %% [markdown]
# # Pattern 1 — Classic Binary Search
#
# Use when:
#
# data is sorted
#
# Examples:
#
# - search
# - lower bound
# - upper bound

# %% [markdown]
# # Pattern 2 — Rotated Binary Search
#
# Use when:
#
# array appears broken
#
# Examples:
#
# - rotated search
# - minimum rotated

# %% [markdown]
# # Pattern 3 — Peak Problems
#
# Use:
#
# direction
#
# instead of exact values.

# %% [markdown]
# # Pattern 4 — Binary Search on Answers
#
# Search:
#
# answer range
#
# Examples:
#
# - koko
# - ship capacity
# - aggressive cows
# - split array

# %% [markdown]
# # Recognition Checklist
#
# Ask:
#
# 1.
#
# Sorted?
#
#
# 2.
#
# Monotonic?
#
#
# 3.
#
# Minimize maximum?
#
#
# 4.
#
# Maximize minimum?

# %% [markdown]
# # Common Mistakes
#
# - wrong boundaries
#
# - infinite loops
#
# - updating wrong side
#
# - searching values
# instead of answers

# %% [markdown]
# # Complexity Summary
#
# Most Binary Search:
#
# Time:
#
# O(log n)
#
# Space:
#
# O(1)

# %% [markdown]
# # Final Takeaway
#
# Binary Search
#
# is not searching.
#
# It is:
#
# eliminating.

# %% [markdown]
# # Module Status
#
# Binary Search
#
# completed.
